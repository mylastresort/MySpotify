# %% [markdown]
# # Template -- MySpotify Research
#
# **Copy this notebook** to start a new algorithm.
# Run the setup cell to load all datasets into the notebook namespace.
#
# | Variable | Shape | Description |
# |----------|-------|-------------|
# | `tracks` | (1 000 000, 4) | track_id . song_id . artist . title |
# | `genres` | (280 831, 3) | track_id . majority_genre . minority_genre |
# | `triplets` | (48 373 586, 3) | user_id . song_id . play_count |
# | `lyrics_long` | (16 845 822, 3) | track_id . word . count |

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from src.data.loader import MySpotifyRecommender

# %%
rs = MySpotifyRecommender.from_files(triplets_sample_rows=100_000)

# %% [markdown]
# ## Research

# %%
# Your code here
