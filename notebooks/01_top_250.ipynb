# %% [markdown]
# # 01 -- Top 250 Most-Played Songs
#
# Returns the **250 globally most-played songs** across all users, ranked by total play count.
#
# ### Algorithm
# 1. Aggregate `play_count` (sum) per `song_id` from the triplets.
# 2. Rank songs by total play count descending and keep the top 250.
# 3. Enrich with artist / title from `tracks`.
#
# ### Output columns
# | Column | Description |
# |--------|-------------|
# | `rank` | 1-250, by total play count |
# | `artist` | Artist name |
# | `title` | Track title |
# | `play_count` | Total plays across all users |

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from src.data import MySpotifyRecommender
from src.models.top_n import top_n_songs

# %%
rs = MySpotifyRecommender.from_files(Path.cwd().parent / "data")
# Out:
#   tracks      (1000000, 4)
#   genres      (280831, 3)
#   triplets    (48373586, 3)
#   lyrics_long (16845943, 3)

# %% [markdown]
# ---
# ## Top N Songs

# %%
a = top_n_songs(rs, n=250, user_id=None)
a[["artist", "title", "play_count"]]
# Out:
# shape: (250, 3)
# ┌─────────────────────────────────┬─────────────────────────────────┬────────────┐
# │ artist                          ┆ title                           ┆ play_count │
# │ ---                             ┆ ---                             ┆ ---        │
# │ str                             ┆ str                             ┆ i64        │
# ╞═════════════════════════════════╪═════════════════════════════════╪════════════╡
# │ Dwight Yoakam                   ┆ You're The One                  ┆ 726885     │
# │ Björk                           ┆ Undo                            ┆ 648239     │
# │ Kings Of Leon                   ┆ Revelry                         ┆ 527893     │
# │ Harmonia                        ┆ Sehr kosmisch                   ┆ 425463     │
# │ Barry Tuckwell/Academy of St M… ┆ Horn Concerto No. 4 in E flat … ┆ 389880     │
# │ …                               ┆ …                               ┆ …          │
# │ Triple Six Mafia                ┆ Now I'm High_ Really High       ┆ 35253      │
# │ The Red Jumpsuit Apparatus      ┆ Face Down (Album Version)       ┆ 35245      │
# │ Linkin Park                     ┆ New Divide (Album Version)      ┆ 35191      │
# │ Selena Gomez & The Scene        ┆ Naturally                       ┆ 35074      │
# │ Creedence Clearwater Revival    ┆ Have You Ever Seen The Rain     ┆ 34831      │
# └─────────────────────────────────┴─────────────────────────────────┴────────────┘

# %%
# for a single user

user_id = rs.triplets["user_id"].sample(1).item()

a = top_n_songs(rs, n=250, user_id=user_id)
a[["artist", "title", "play_count"]]
# Out:
# shape: (84, 3)
# ┌────────────────────────────────┬─────────────────────────────────┬────────────┐
# │ artist                         ┆ title                           ┆ play_count │
# │ ---                            ┆ ---                             ┆ ---        │
# │ str                            ┆ str                             ┆ i64        │
# ╞════════════════════════════════╪═════════════════════════════════╪════════════╡
# │ No Te Va Gustar                ┆ No Lo Ves                       ┆ 17         │
# │ Elvis Costello & The Imposters ┆ The Name Of This Thing Is Not … ┆ 16         │
# │ Elmer Bernstein                ┆ Blythe                          ┆ 7          │
# │ Underworld                     ┆ Born Slippy                     ┆ 6          │
# │ Los Inquietos                  ┆ No le temas al amor             ┆ 6          │
# │ …                              ┆ …                               ┆ …          │
# │ Gorillaz                       ┆ Broken                          ┆ 1          │
# │ Belanova                       ┆ Por Ti                          ┆ 1          │
# │ Allison Moorer                 ┆ Goodbye To The Ground           ┆ 1          │
# │ Gorillaz                       ┆ Welcome To The World of The Pl… ┆ 1          │
# │ Corinne Bailey Rae             ┆ Are You Here                    ┆ 1          │
# └────────────────────────────────┴─────────────────────────────────┴────────────┘
