# %% [markdown]
# # 01 -- Top 250 Most-Played Songs
#
# Returns the **250 globally most-played songs** across all users, ranked by total play count.
#
# ### Algorithm
# 1. Aggregate `play_count` (sum) per `song_id` from the triplets.
# 2. Rank songs by total play count descending and keep the top 250.
# 3. Enrich with artist / title from `tracks`.
#
# ### Output columns
# | Column | Description |
# |--------|-------------|
# | `rank` | 1-250, by total play count |
# | `artist` | Artist name |
# | `title` | Track title |
# | `play_count` | Total plays across all users |

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from src.data.loader import MySpotifyRecommender
from src.models.top_n import top_n_songs

# %%
rs = MySpotifyRecommender.from_files(Path.cwd().parent / "data")
# Out:
# Data dir    : /home/samy/MySpotify/data
# Source      : uncleaned raw files (parsed in place)
# Saved parsed CSVs to /home/samy/MySpotify/data/csv
#
#   tracks      (1000000, 4)
#   genres      (280831, 3)
#   triplets    (48373586, 3)
#   lyrics_long (16845822, 3)

# %% [markdown]
# ---
# ## Top N Songs

# %%
a = top_n_songs(rs, n=250, user_id=None)
a[["artist", "title", "play_count"]]
# Out:
#                                                 artist  \
# 0                                        Dwight Yoakam
# 1                                                Björk
# 2                                        Kings Of Leon
# 3                                             Harmonia
# 4    Barry Tuckwell/Academy of St Martin-in-the-Fie...
# ..                                                 ...
# 245                                   Triple Six Mafia
# 246                         The Red Jumpsuit Apparatus
# 247                                        Linkin Park
# 248                           Selena Gomez & The Scene
# 249                       Creedence Clearwater Revival
#
#                                                  title  play_count
# 0                                       You're The One      726885
# 1                                                 Undo      648239
# 2                                              Revelry      527893
# 3                                        Sehr kosmisch      425463
# 4    Horn Concerto No. 4 in E flat K495: II. Romanc...      389880
# ..                                                 ...         ...
# 245                          Now I'm High_ Really High       35253
# 246                          Face Down (Album Version)       35245
# 247                         New Divide (Album Version)       35191
# 248                                          Naturally       35074
# 249                        Have You Ever Seen The Rain       34831
#
# [250 rows x 3 columns]

# %%
# for a single user

user_id = rs.triplets["user_id"].sample(1).values[0]

a = top_n_songs(rs, n=250, user_id=user_id)
a[["artist", "title", "play_count"]]
# Out:
#                          artist  \
# 0                       Mos Def
# 1                       Ramones
# 2                  3 Doors Down
# 3   Cliff Richard & The Shadows
# 4                   Queensryche
# 5                Kevin Blechdom
# 6                Måns Zelmerlöw
# 7                Edwin Yearwood
# 8     Big Punisher;The Beatnuts
# 9    Killa Tay and Laroo T.H.H.
# 10                  Arcade Fire
# 11                         Muse
# 12                         Muse
# 13                Flowing Tears
# 14                         Muse
# 15                 Flying Lotus
# 16                         Muse
# 17                         Muse
# 18                         Muse
