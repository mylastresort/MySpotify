# %% [markdown]
# # 01 -- Top 250 Most-Played Songs
#
# Returns the **250 globally most-played songs** across all users, ranked by total play count.
#
# ### Algorithm
# 1. Aggregate `play_count` (sum) per `song_id` from the triplets.
# 2. Rank songs by total play count descending and keep the top 250.
# 3. Enrich with artist / title from `tracks`.
#
# ### Output columns
# | Column | Description |
# |--------|-------------|
# | `rank` | 1-250, by total play count |
# | `artist` | Artist name |
# | `title` | Track title |
# | `play_count` | Total plays across all users |

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from src.data import MySpotifyRecommender
from src.models.top_n import top_n_songs

# %%
rs = MySpotifyRecommender.from_files(Path.cwd().parent / "data")
# Out:
#   tracks      (1000000, 4)
#   genres      (280831, 3)
#   triplets    (48373586, 3)
#   lyrics_long (16845943, 3)

# %% [markdown]
# ---
# ## Top N Songs

# %%
a = top_n_songs(rs, n=250, user_id=None)
a
# Out:
# shape: (250, 4)
# ┌──────────────┬─────────────────────────────────┬─────────────────────────────────┬────────────┐
# │ index_number ┆ artist_name                     ┆ track_title                     ┆ play_count │
# │ ---          ┆ ---                             ┆ ---                             ┆ ---        │
# │ u32          ┆ str                             ┆ str                             ┆ i64        │
# ╞══════════════╪═════════════════════════════════╪═════════════════════════════════╪════════════╡
# │ 0            ┆ Dwight Yoakam                   ┆ You're The One                  ┆ 726885     │
# │ 1            ┆ Björk                           ┆ Undo                            ┆ 648239     │
# │ 2            ┆ Kings Of Leon                   ┆ Revelry                         ┆ 527893     │
# │ 3            ┆ Harmonia                        ┆ Sehr kosmisch                   ┆ 425463     │
# │ 4            ┆ Barry Tuckwell/Academy of St M… ┆ Horn Concerto No. 4 in E flat … ┆ 389880     │
# │ …            ┆ …                               ┆ …                               ┆ …          │
# │ 245          ┆ Triple Six Mafia                ┆ Now I'm High_ Really High       ┆ 35253      │
# │ 246          ┆ The Red Jumpsuit Apparatus      ┆ Face Down (Album Version)       ┆ 35245      │
# │ 247          ┆ Linkin Park                     ┆ New Divide (Album Version)      ┆ 35191      │
# │ 248          ┆ Selena Gomez & The Scene        ┆ Naturally                       ┆ 35074      │
# │ 249          ┆ Creedence Clearwater Revival    ┆ Have You Ever Seen The Rain     ┆ 34831      │
# └──────────────┴─────────────────────────────────┴─────────────────────────────────┴────────────┘

# %%
# for a single user

user_id = rs.triplets["user_id"].sample(1).item()

a = top_n_songs(rs, n=250, user_id=user_id)
a
# Out:
# shape: (12, 4)
# ┌──────────────┬─────────────────────────┬───────────────────────────┬────────────┐
# │ index_number ┆ artist_name             ┆ track_title               ┆ play_count │
# │ ---          ┆ ---                     ┆ ---                       ┆ ---        │
# │ u32          ┆ str                     ┆ str                       ┆ i64        │
# ╞══════════════╪═════════════════════════╪═══════════════════════════╪════════════╡
# │ 0            ┆ G. Love                 ┆ Christmas Baby            ┆ 8          │
# │ 1            ┆ Five Iron Frenzy        ┆ Canada                    ┆ 6          │
# │ 2            ┆ A Perfect Circle        ┆ The Hollow                ┆ 5          │
# │ 3            ┆ Flight Of The Conchords ┆ Au Revoir (Album Version) ┆ 5          │
# │ 4            ┆ Snow Patrol             ┆ Make This Go On Forever   ┆ 2          │
# │ …            ┆ …                       ┆ …                         ┆ …          │
# │ 7            ┆ The Temper Trap         ┆ Love Lost                 ┆ 1          │
# │ 8            ┆ Steel Pulse             ┆ K.K.K.                    ┆ 1          │
# │ 9            ┆ Base Ball Bear          ┆ Sayonara-Nostalgia        ┆ 1          │
# │ 10           ┆ Angels and Airwaves     ┆ The Gift                  ┆ 1          │
# │ 11           ┆ LU                      ┆ Una Confusion             ┆ 1          │
# └──────────────┴─────────────────────────┴───────────────────────────┴────────────┘
