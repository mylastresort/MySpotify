# %% [markdown]
# # 02 -- Top 100 Most-Played Songs for a Given Genre
#
# Returns the **100 globally most-played songs for a given majority genre**, sorted by total play count descending.
#
# ### Algorithm
# 1. Deduplicate `tracks` by `song_id` (keep the first `track_id`) so a song whose genre tag sits on a non-canonical track row is not double-counted.
# 2. Join with `genres` (via `track_id`) using only `majority_genre`.
# 3. Join with `triplets` (via `song_id`) and aggregate `play_count` (sum) per `song_id`.
# 4. Filter to the requested genre, keep the top 100 by total play count.
#
# ### Output columns
# | Column | Description |
# |--------|-------------|
# | `rank` | 1-100 index, by total play count (descending) |
# | `artist` | Artist name |
# | `title` | Track title |
# | `play_count` | Total plays across all users |

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from src.data import MySpotifyRecommender
from src.models.top_n_genre import top_n_per_genre

# %%
rs = MySpotifyRecommender.from_files(Path.cwd().parent / "data")
# Out:
#   tracks      (1000000, 4)
#   genres      (280831, 3)
#   triplets    (48373586, 3)
#   lyrics_long (16845943, 3)

# %% [markdown]
# ---
# ## Top N Genre Songs

# %%
genres = rs.genres["majority_genre"].unique()
print(f"Available genres ({len(genres)}): {sorted(genres)}")
# Out:
# Available genres (15): ['Blues', 'Country', 'Electronic', 'Folk', 'Jazz', 'Latin', 'Metal', 'New Age', 'Pop', 'Punk', 'Rap', 'Reggae', 'RnB', 'Rock', 'World']

# %%
top100_rock = top_n_per_genre(rs, "Rock", n=100)
top100_rock
# Out:
# shape: (100, 4)
# ┌──────────────┬───────────────┬───────────────────┬────────────┐
# │ index_number ┆ artist_name   ┆ track_title       ┆ play_count │
# │ ---          ┆ ---           ┆ ---               ┆ ---        │
# │ u32          ┆ str           ┆ str               ┆ i64        │
# ╞══════════════╪═══════════════╪═══════════════════╪════════════╡
# │ 0            ┆ Björk         ┆ Undo              ┆ 648239     │
# │ 1            ┆ Kings Of Leon ┆ Revelry           ┆ 527893     │
# │ 2            ┆ Harmonia      ┆ Sehr kosmisch     ┆ 425463     │
# │ 3            ┆ OneRepublic   ┆ Secrets           ┆ 292642     │
# │ 4            ┆ Tub Ring      ┆ Invalid           ┆ 268353     │
# │ …            ┆ …             ┆ …                 ┆ …          │
# │ 95           ┆ Metric        ┆ Gold Guns Girls   ┆ 28148      │
# │ 96           ┆ Pearl Jam     ┆ Encore Break      ┆ 27579      │
# │ 97           ┆ Daughtry      ┆ No Surprise       ┆ 27187      │
# │ 98           ┆ Eric Clapton  ┆ Tears In Heaven   ┆ 26999      │
# │ 99           ┆ Nick Lowe     ┆ All Men Are Liars ┆ 26683      │
# └──────────────┴───────────────┴───────────────────┴────────────┘

# %%
top100_rock = top_n_per_genre(rs, "Rap", n=100)
top100_rock
# Out:
# shape: (100, 4)
# ┌──────────────┬──────────────────────┬─────────────────┬────────────┐
# │ index_number ┆ artist_name          ┆ track_title     ┆ play_count │
# │ ---          ┆ ---                  ┆ ---             ┆ ---        │
# │ u32          ┆ str                  ┆ str             ┆ i64        │
# ╞══════════════╪══════════════════════╪═════════════════╪════════════╡
# │ 0            ┆ Alliance Ethnik      ┆ Représente      ┆ 241669     │
# │ 1            ┆ Beastie Boys         ┆ The Maestro     ┆ 72381      │
# │ 2            ┆ Eminem               ┆ Without Me      ┆ 63918      │
# │ 3            ┆ Black Eyed Peas      ┆ Imma Be         ┆ 62438      │
# │ 4            ┆ Kid Cudi             ┆ Up Up & Away    ┆ 59810      │
# │ …            ┆ …                    ┆ …               ┆ …          │
# │ 95           ┆ Shwayze              ┆ Buzzin'         ┆ 7384       │
# │ 96           ┆ Orishas              ┆ El Kilo         ┆ 7324       │
# │ 97           ┆ Snoop Dogg           ┆ Sexual Eruption ┆ 7171       │
# │ 98           ┆ Bone Thugs-N-Harmony ┆ Tha Crossroads  ┆ 7124       │
# │ 99           ┆ Orishas              ┆ Habana          ┆ 6998       │
# └──────────────┴──────────────────────┴─────────────────┴────────────┘

# %%
top100_rock = top_n_per_genre(rs, "Electronic", n=100)
top100_rock
# Out:
# shape: (100, 4)
# ┌──────────────┬──────────────────────┬─────────────────────────────────┬────────────┐
# │ index_number ┆ artist_name          ┆ track_title                     ┆ play_count │
# │ ---          ┆ ---                  ┆ ---                             ┆ ---        │
# │ u32          ┆ str                  ┆ str                             ┆ i64        │
# ╞══════════════╪══════════════════════╪═════════════════════════════════╪════════════╡
# │ 0            ┆ Southside Spinners   ┆ Luvstruck                       ┆ 84225      │
# │ 1            ┆ The Black Keys       ┆ Tighten Up                      ┆ 81179      │
# │ 2            ┆ Deadmau5             ┆ Ghosts 'n' Stuff (Original Ins… ┆ 63951      │
# │ 3            ┆ Daft Punk            ┆ Harder Better Faster Stronger   ┆ 63170      │
# │ 4            ┆ Clara Hill           ┆ Clara meets Slope - Hard To Sa… ┆ 58887      │
# │ …            ┆ …                    ┆ …                               ┆ …          │
# │ 95           ┆ Nicolette            ┆ No Government                   ┆ 9541       │
# │ 96           ┆ Two Door Cinema Club ┆ Eat That Up_ It's Good For You  ┆ 9524       │
# │ 97           ┆ Moby                 ┆ Why Does My Heart Feel So Bad?… ┆ 9491       │
# │ 98           ┆ Death In Vegas       ┆ Girls                           ┆ 9490       │
# │ 99           ┆ Johan Gielen         ┆ Flash                           ┆ 9431       │
# └──────────────┴──────────────────────┴─────────────────────────────────┴────────────┘

# %%
user_1 = rs.triplets["user_id"].unique().head(1).item()

print(f"User 1: {user_1}")

top100_rock_user_1 = top_n_per_genre(
    rs,
    "Rock",
    n=100,
    user_id=user_1,
)
# Out:
# User 1: b80344d063b5ccb3212f76538f3d9e43d87dca9e

# %%
top100_rock_user_1
# Out:
# shape: (37, 4)
# ┌──────────────┬─────────────────────┬──────────────────────────────┬────────────┐
# │ index_number ┆ artist_name         ┆ track_title                  ┆ play_count │
# │ ---          ┆ ---                 ┆ ---                          ┆ ---        │
# │ u32          ┆ str                 ┆ str                          ┆ i64        │
# ╞══════════════╪═════════════════════╪══════════════════════════════╪════════════╡
# │ 0            ┆ Héroes del Silencio ┆ Apuesta Por El Rock 'N' Roll ┆ 5          │
# │ 1            ┆ Chris Bell          ┆ Speed Of Sound               ┆ 2          │
# │ 2            ┆ Josh Rouse          ┆ It's The Night Time          ┆ 1          │
# │ 3            ┆ Josh Rouse          ┆ Under Cold Blue Stars        ┆ 1          │
# │ 4            ┆ Foo Fighters        ┆ Learn To Fly                 ┆ 1          │
# │ …            ┆ …                   ┆ …                            ┆ …          │
# │ 32           ┆ Josh Rouse          ┆ Hollywood Bass Player        ┆ 1          │
# │ 33           ┆ R.E.M.              ┆ Laughing                     ┆ 1          │
# │ 34           ┆ Angus & Julia Stone ┆ Jewels And Gold              ┆ 1          │
# │ 35           ┆ Josh Rouse          ┆ Italian Dry Ice              ┆ 1          │
# │ 36           ┆ Jimmy Eat World     ┆ The Middle                   ┆ 1          │
# └──────────────┴─────────────────────┴──────────────────────────────┴────────────┘
