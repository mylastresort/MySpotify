# %% [markdown]
# # 02 -- Top 100 Most-Played Songs for a Given Genre
#
# Returns the **100 globally most-played songs for a given majority genre**, sorted by total play count descending.
#
# ### Algorithm
# 1. Aggregate `play_count` (sum) per `song_id` from the triplets.
# 2. Join with `tracks` (via `song_id`) to obtain `track_id`, artist, and title.
# 3. Join with `genres` (via `track_id`) using only `majority_genre`.
# 4. Filter to the requested genre, keep the top 100 by total play count.
#
# ### Output columns
# | Column | Description |
# |--------|-------------|
# | `rank` | 1-100 index, by total play count (descending) |
# | `artist` | Artist name |
# | `title` | Track title |
# | `play_count` | Total plays across all users |

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from src.data.loader import MySpotifyRecommender
from src.models.top_n_genre import top_n_per_genre

# %%
rs = MySpotifyRecommender.from_files(Path.cwd().parent / "data")
# Out:
# Data dir    : /home/samy/MySpotify/data
# Source      : cleaned CSVs (/home/samy/MySpotify/data/csv)
#
#   tracks      (1000000, 4)
#   genres      (280831, 3)
#   triplets    (48373586, 3)
#   lyrics_long (16845822, 3)

# %% [markdown]
# ---
# ## Top N Genre Songs

# %%
genres = rs.genres["majority_genre"].unique()
print(f"Available genres ({len(genres)}): {sorted(genres)}")
# Out:
# Available genres (15): ['Blues', 'Country', 'Electronic', 'Folk', 'Jazz', 'Latin', 'Metal', 'New Age', 'Pop', 'Punk', 'Rap', 'Reggae', 'RnB', 'Rock', 'World']

# %%
top100_rock = top_n_per_genre(rs, "Rock", n=100)
top100_rock[["artist", "title", "play_count"]]
# Out:
#                 artist                          title  play_count
# 0                Björk                           Undo    648239.0
# 1        Kings Of Leon                        Revelry    527893.0
# 2             Harmonia                  Sehr kosmisch    425463.0
# 3          OneRepublic                        Secrets    292642.0
# 4             Tub Ring                        Invalid    268353.0
# ..                 ...                            ...         ...
# 95     Days Of The New                       Provider     30146.0
# 96    Hollywood Undead                Everywhere I Go     30030.0
# 97             Phoenix                          Lasso     29884.0
# 98          Eddy Grant                Electric Avenue     29781.0
# 99  The Rolling Stones  Angie (1993 Digital Remaster)     29754.0
#
# [100 rows x 3 columns]

# %%
user_1 = rs.triplets["user_id"].drop_duplicates().head(1).iloc[0]

print(f"User 1: {user_1}")

top100_rock_user_1 = top_n_per_genre(
    rs,
    "Rock",
    n=100,
    user_id=user_1,
)
# Out:
# User 1: b80344d063b5ccb3212f76538f3d9e43d87dca9e

# %%
top100_rock_user_1[["artist", "title", "play_count"]]
# Out:
#                  artist                              title  play_count
# 0   Héroes del Silencio       Apuesta Por El Rock 'N' Roll         5.0
# 1            Chris Bell                     Speed Of Sound         2.0
# 2            John Mayer               Love Song For No One         1.0
# 3            Josh Rouse                     Nice To Fit In         1.0
# 4            Josh Rouse                Domesticated Lovers         1.0
# 5           Andrew Bird                              Oh No         1.0
# 6           Takka Takka                              Fever         1.0
# 7               Incubus                              Drive         1.0
# 8            Josh Rouse                It's The Night Time         1.0
# 9       Jimmy Eat World                         The Middle         1.0
# 10           The B-52's                         Love Shack         1.0
# 11              Sublime                         Right Back         1.0
# 12         Bishop Allen                               Rain         1.0
# 13      Eric Hutchinson  Outside Villanova (Album Version)         1.0
# 14               R.E.M.                           Laughing         1.0
# 15           Josh Rouse                       Ugly Stories         1.0
# 16         Jack Johnson                           The Cove         1.0
# 17           Josh Rouse              Hollywood Bass Player         1.0
# 18          Fleet Foxes                          Sun Giant         1.0
# 19          Fleet Foxes                He Doesn't Know Why         1.0
# 20  Angus & Julia Stone                    Jewels And Gold         1.0
# 21              Incubus                        Are You In?         1.0
# 22         Foo Fighters                     Stacked Actors         1.0
# 23         Foo Fighters                     Gimme Stitches         1.0
# 24         Foo Fighters                          Generator         1.0
# 25           John Mayer                                 83         1.0
# 26           Josh Rouse                      Street Lights         1.0
# 27           Josh Rouse                            Pilgrim         1.0
# 28         Foo Fighters                           Breakout         1.0
# 29           Josh Rouse                   My Love Has Gone         1.0
# 30        Kings Of Leon                              Trani         1.0
# 31             Harmonia                      Sehr kosmisch         1.0
# 32           Josh Rouse             Winter In The Hamptons         1.0
# 33           John Mayer                          City Love         1.0
# 34          Fleet Foxes                        Ragged Wood         1.0
# 35       Porcupine Tree                        Neural Rust         1.0
# 36           Josh Rouse                    Italian Dry Ice         1.0
# 37         Foo Fighters                       Learn To Fly         1.0
# 38           Josh Rouse          Nothing Gives Me Pleasure         1.0
# 39         Jack Johnson                     Constellations         1.0
# 40           Josh Rouse              Under Cold Blue Stars         1.0
